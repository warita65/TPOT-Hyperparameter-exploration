# %% [markdown]
# # TPOT using KNN

# %%
import pandas as pd
import numpy as np
from tpot import TPOTClassifier
from sklearn.model_selection import train_test_split
from pmlb import classification_dataset_names
from pmlb import fetch_data

# %% [markdown]
# ### Banana

# %%
banana = fetch_data('banana', local_cache_dir = './')

# %%
n_observations = banana.size

# %%
features_banana = banana.drop('target', axis = 1)

# %%
train_banana_features, test_banana_features, train_banana_target, test_banana_target = train_test_split(features_banana, banana['target'], train_size= 0.75, test_size = 0.25, random_state=42)

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,101),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier')
tpot.fit(train_banana_features, train_banana_target)
print(tpot.score(test_banana_features, test_banana_target))
tpot.export('tpot_KNN_banana3.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.9066666666666666
# Generation 2 - Current best internal CV score: 0.9066666666666666
# Generation 3 - Current best internal CV score: 0.9069182389937108
# Generation 4 - Current best internal CV score: 0.9071698113207546
# Generation 5 - Current best internal CV score: 0.9074213836477988
# Generation 6 - Current best internal CV score: 0.9074213836477988
# Generation 7 - Current best internal CV score: 0.9074213836477988
# Generation 8 - Current best internal CV score: 0.9074213836477988
# Generation 9 - Current best internal CV score: 0.9074213836477988
# Generation 10 - Current best internal CV score: 0.9074213836477988
# Generation 11 - Current best internal CV score: 0.9074213836477988
# Generation 12 - Current best internal CV score: 0.9074213836477988
# Generation 13 - Current best internal CV score: 0.9074213836477988
# Generation 14 - Current best internal CV score: 0.9074213836477988
# ...

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,int(n_observations/2)),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config , template = 'Classifier')
tpot.fit(train_banana_features, train_banana_target)
print(tpot.score(test_banana_features, test_banana_target))
tpot.export('tpot_KNN_banana_half2.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.898867924528302
# Generation 2 - Current best internal CV score: 0.9041509433962265
# Generation 3 - Current best internal CV score: 0.9064150943396226
# Generation 4 - Current best internal CV score: 0.9064150943396226
# Generation 5 - Current best internal CV score: 0.9064150943396226
# Generation 6 - Current best internal CV score: 0.9064150943396226
# Generation 7 - Current best internal CV score: 0.9064150943396226
# Generation 8 - Current best internal CV score: 0.9064150943396226
# Generation 9 - Current best internal CV score: 0.9064150943396226
# Generation 10 - Current best internal CV score: 0.9064150943396226
# Generation 11 - Current best internal CV score: 0.9064150943396226
# Generation 12 - Current best internal CV score: 0.9064150943396226
# Generation 13 - Current best internal CV score: 0.9064150943396226
# Generation 14 - Current best internal CV score: 0.9064150943396226
# ...

# %% [markdown]
# ### Contraceptive

# %%
contraceptive = fetch_data('contraceptive')

# %%
n_observations = contraceptive.size
# Out:
# (1473, 10)

# %%
features_contraceptive = contraceptive.drop('target', axis =1)

# %%
train_contra_features, test_contra_features, train_contra_target, test_contra_target = train_test_split(features_contraceptive, contraceptive['target'], train_size=0.75, test_size = 0.25, random_state=42)

# %%
#KNN with changed hyperparameters
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,101),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier')

tpot.fit(train_contra_features, train_contra_target)
print(tpot.score(test_contra_features, test_contra_target))
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.5416865487453723
# Generation 2 - Current best internal CV score: 0.5416865487453723
# Generation 3 - Current best internal CV score: 0.543475935828877
# Generation 4 - Current best internal CV score: 0.543475935828877
# Generation 5 - Current best internal CV score: 0.543475935828877
# Generation 6 - Current best internal CV score: 0.543475935828877
# Generation 7 - Current best internal CV score: 0.543475935828877
# Generation 8 - Current best internal CV score: 0.543475935828877
# Generation 9 - Current best internal CV score: 0.543475935828877
# Generation 10 - Current best internal CV score: 0.543475935828877
# Generation 11 - Current best internal CV score: 0.543475935828877
# Generation 12 - Current best internal CV score: 0.543475935828877
# Generation 13 - Current best internal CV score: 0.543475935828877
# Generation 14 - Current best internal CV score: 0.543475935828877
# ...

# %%
tpot.export('tpot_KNN_contraception3.py')

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,int(n_observations/2)),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config , template = 'Classifier')

tpot.fit(train_contra_features, train_contra_target)
print(tpot.score(test_contra_features, test_contra_target))
tpot.export('tpot_KNN_contraception_half2.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.5298807075277663
# Generation 2 - Current best internal CV score: 0.5416865487453723
# Generation 3 - Current best internal CV score: 0.5416865487453723
# Generation 4 - Current best internal CV score: 0.5416865487453723
# Generation 5 - Current best internal CV score: 0.5416865487453723
# Generation 6 - Current best internal CV score: 0.5416865487453723
# Generation 7 - Current best internal CV score: 0.5416865487453723
# Generation 8 - Current best internal CV score: 0.5416865487453723
# Generation 9 - Current best internal CV score: 0.5416865487453723
# Generation 10 - Current best internal CV score: 0.5416865487453723
# Generation 11 - Current best internal CV score: 0.5452735499794323
# Generation 12 - Current best internal CV score: 0.5452776635129576
# Generation 13 - Current best internal CV score: 0.5507363225010283
# Generation 14 - Current best internal CV score: 0.5507363225010283
# ...

# %% [markdown]
# ### Agaricus-lepiota

# %%
from pmlb import fetch_data
agaricus = fetch_data('agaricus-lepiota')

# %%
n_observations = agaricus.size
# Out:
# (8145, 23)

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,101),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
agaricus_features = agaricus.drop('target', axis=1)

# %%
train_aga_features, test_aga_features, train_aga_target, test_aga_target = train_test_split(agaricus_features, agaricus['target'], train_size =0.75, test_size = 0.25, random_state =42)

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_aga_features, train_aga_target)
print(tpot.score(test_aga_features, test_aga_target))
tpot.export('tpot_KNN_aga3.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 1.0
# Generation 2 - Current best internal CV score: 1.0
# Generation 3 - Current best internal CV score: 1.0
# Generation 4 - Current best internal CV score: 1.0
# Generation 5 - Current best internal CV score: 1.0
# Generation 6 - Current best internal CV score: 1.0
# Generation 7 - Current best internal CV score: 1.0
# Generation 8 - Current best internal CV score: 1.0
# Generation 9 - Current best internal CV score: 1.0
# Generation 10 - Current best internal CV score: 1.0
# Generation 11 - Current best internal CV score: 1.0
# Generation 12 - Current best internal CV score: 1.0
# Generation 13 - Current best internal CV score: 1.0
# Generation 14 - Current best internal CV score: 1.0
# Generation 15 - Current best internal CV score: 1.0
# Generation 16 - Current best internal CV score: 1.0
# Generation 17 - Current best internal CV score: 1.0
# Generation 18 - Current best internal CV score: 1.0
# ...

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,int(n_observations/2)),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_aga_features, train_aga_target)
print(tpot.score(test_aga_features, test_aga_target))
tpot.export('tpot_KNN_aga_half2.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.9864119587523843
# Generation 2 - Current best internal CV score: 0.999181401309061
# Generation 3 - Current best internal CV score: 1.0
# Generation 4 - Current best internal CV score: 1.0
# Generation 5 - Current best internal CV score: 1.0
# Generation 6 - Current best internal CV score: 1.0
# Generation 7 - Current best internal CV score: 1.0
# Generation 8 - Current best internal CV score: 1.0
# Generation 9 - Current best internal CV score: 1.0
# Generation 10 - Current best internal CV score: 1.0
# Generation 11 - Current best internal CV score: 1.0
# Generation 12 - Current best internal CV score: 1.0
# Generation 13 - Current best internal CV score: 1.0
# Generation 14 - Current best internal CV score: 1.0
# Generation 15 - Current best internal CV score: 1.0
# Generation 16 - Current best internal CV score: 1.0
# Generation 17 - Current best internal CV score: 1.0
# Generation 18 - Current best internal CV score: 1.0
# ...

# %% [markdown]
# ### Appendicitis

# %%
appendicitis = fetch_data('appendicitis')
n_observations = appendicitis.size

# %%
appendicitis_features = appendicitis.drop('target', axis=1)
train_appen_features, test_appen_features, train_appen_target, test_appen_target = train_test_split(appendicitis_features, appendicitis['target'], train_size = 0.75, test_size = 0.25, random_state = 42)

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,101),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_appen_features, train_appen_target)
print(tpot.score(test_appen_features, test_appen_target))
tpot.export('tpot_KNN_apendicitis4.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.9116666666666667
# Generation 2 - Current best internal CV score: 0.9116666666666667
# Generation 3 - Current best internal CV score: 0.9116666666666667
# Generation 4 - Current best internal CV score: 0.9116666666666667
# Generation 5 - Current best internal CV score: 0.9116666666666667
# Generation 6 - Current best internal CV score: 0.9116666666666667
# Generation 7 - Current best internal CV score: 0.9116666666666667
# Generation 8 - Current best internal CV score: 0.9116666666666667
# Generation 9 - Current best internal CV score: 0.9116666666666667
# Generation 10 - Current best internal CV score: 0.9116666666666667
# Generation 11 - Current best internal CV score: 0.9116666666666667
# Generation 12 - Current best internal CV score: 0.9116666666666667
# Generation 13 - Current best internal CV score: 0.9116666666666667
# Generation 14 - Current best internal CV score: 0.9116666666666667
# ...

# %%
#KNN with n_observations/2 values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,int(n_observations/2)),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_appen_features, train_appen_target)
print(tpot.score(test_appen_features, test_appen_target))
tpot.export('tpot_KNN_apendicitis_half2.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.8983333333333334
# Generation 2 - Current best internal CV score: 0.9116666666666667
# Generation 3 - Current best internal CV score: 0.9116666666666667
# Generation 4 - Current best internal CV score: 0.9116666666666667
# Generation 5 - Current best internal CV score: 0.9116666666666667
# Generation 6 - Current best internal CV score: 0.9116666666666667
# Generation 7 - Current best internal CV score: 0.9116666666666667
# Generation 8 - Current best internal CV score: 0.9116666666666667
# Generation 9 - Current best internal CV score: 0.9116666666666667
# Generation 10 - Current best internal CV score: 0.9116666666666667
# Generation 11 - Current best internal CV score: 0.9116666666666667
# Generation 12 - Current best internal CV score: 0.9116666666666667
# Generation 13 - Current best internal CV score: 0.9116666666666667
# Generation 14 - Current best internal CV score: 0.9116666666666667
# ...

# %% [markdown]
# ### Corral

# %%
corral = fetch_data('corral')
n_observations = corral.size
# Out:
# (160, 7)

# %%
corral_features = corral.drop('target', axis = 1)
train_features, test_features, train_target, test_target = train_test_split(corral_features, corral['target'], train_size = 0.75, test_size = 0.25, random_state = 42)

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,101),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_features, train_target)
print(tpot.score(test_features, test_target))
tpot.export('tpot_KNN_corral3.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.95
# Generation 2 - Current best internal CV score: 0.95
# Generation 3 - Current best internal CV score: 0.95
# Generation 4 - Current best internal CV score: 0.95
# Generation 5 - Current best internal CV score: 0.95
# Generation 6 - Current best internal CV score: 0.95
# Generation 7 - Current best internal CV score: 0.95
# Generation 8 - Current best internal CV score: 0.95
# Generation 9 - Current best internal CV score: 0.95
# Generation 10 - Current best internal CV score: 0.95
# Generation 11 - Current best internal CV score: 0.95
# Generation 12 - Current best internal CV score: 0.95
# Generation 13 - Current best internal CV score: 0.95
# Generation 14 - Current best internal CV score: 0.95
# Generation 15 - Current best internal CV score: 0.95
# Generation 16 - Current best internal CV score: 0.95
# Generation 17 - Current best internal CV score: 0.95
# Generation 18 - Current best internal CV score: 0.95
# ...

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,int(n_observations/2)),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_features, train_target)
print(tpot.score(test_features, test_target))
tpot.export('tpot_KNN_corral_half2.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.95
# Generation 2 - Current best internal CV score: 0.95
# Generation 3 - Current best internal CV score: 0.95
# Generation 4 - Current best internal CV score: 0.95
# Generation 5 - Current best internal CV score: 0.95
# Generation 6 - Current best internal CV score: 0.95
# Generation 7 - Current best internal CV score: 0.95
# Generation 8 - Current best internal CV score: 0.95
# Generation 9 - Current best internal CV score: 0.95
# Generation 10 - Current best internal CV score: 0.95
# Generation 11 - Current best internal CV score: 0.95
# Generation 12 - Current best internal CV score: 0.95
# Generation 13 - Current best internal CV score: 0.95
# Generation 14 - Current best internal CV score: 0.95
# Generation 15 - Current best internal CV score: 0.95
# Generation 16 - Current best internal CV score: 0.95
# Generation 17 - Current best internal CV score: 0.95
# Generation 18 - Current best internal CV score: 0.95
# ...

# %% [markdown]
# ### Hepatitis

# %%
hepatitis = fetch_data('hepatitis')
n_observations = hepatitis.size
# Out:
# (155, 20)

# %%
hepatitis_features = hepatitis.drop('target', axis = 1)
train_features, test_features, train_target, test_target = train_test_split(hepatitis_features, hepatitis['target'], train_size = 0.75, test_size = 0.25, random_state = 42)

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,101),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_features, train_target)
print(tpot.score(test_features, test_target))
tpot.export('tpot_KNN_hepatitis3.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.8105072463768117
# Generation 2 - Current best internal CV score: 0.8105072463768117
# Generation 3 - Current best internal CV score: 0.8105072463768117
# Generation 4 - Current best internal CV score: 0.8105072463768117
# Generation 5 - Current best internal CV score: 0.8105072463768117
# Generation 6 - Current best internal CV score: 0.8105072463768117
# Generation 7 - Current best internal CV score: 0.8105072463768117
# Generation 8 - Current best internal CV score: 0.8105072463768117
# Generation 9 - Current best internal CV score: 0.8105072463768117
# Generation 10 - Current best internal CV score: 0.8105072463768117
# Generation 11 - Current best internal CV score: 0.8105072463768117
# Generation 12 - Current best internal CV score: 0.8105072463768117
# Generation 13 - Current best internal CV score: 0.8105072463768117
# Generation 14 - Current best internal CV score: 0.8105072463768117
# ...

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,int(n_observations/2)),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_features, train_target)
print(tpot.score(test_features, test_target))
tpot.export('tpot_KNN_hepatitis_half2.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.8105072463768117
# Generation 2 - Current best internal CV score: 0.8105072463768117
# Generation 3 - Current best internal CV score: 0.8105072463768117
# Generation 4 - Current best internal CV score: 0.8105072463768117
# Generation 5 - Current best internal CV score: 0.8105072463768117
# Generation 6 - Current best internal CV score: 0.8105072463768117
# Generation 7 - Current best internal CV score: 0.8105072463768117
# Generation 8 - Current best internal CV score: 0.8105072463768117
# Generation 9 - Current best internal CV score: 0.8105072463768117
# Generation 10 - Current best internal CV score: 0.8105072463768117
# Generation 11 - Current best internal CV score: 0.8105072463768117
# Generation 12 - Current best internal CV score: 0.8105072463768117
# Generation 13 - Current best internal CV score: 0.8105072463768117
# Generation 14 - Current best internal CV score: 0.8105072463768117
# ...

# %% [markdown]
# ### Segmentation

# %%
segmentation = fetch_data('segmentation')

# %%
n_observations =  segmentation.size
# Out:
# (2310, 20)

# %%
segmentation_features = segmentation.drop('target', axis = 1)
train_features, test_features, train_target, test_target = train_test_split(segmentation_features, segmentation['target'], train_size = 0.75, test_size = 0.25, random_state = 42)

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,101),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_features, train_target)
print(tpot.score(test_features, test_target))
tpot.export('tpot_knn_segmentation3.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.9630557545268278
# Generation 2 - Current best internal CV score: 0.9630557545268278
# Generation 3 - Current best internal CV score: 0.9630557545268278
# Generation 4 - Current best internal CV score: 0.9630557545268278
# Generation 5 - Current best internal CV score: 0.9630557545268278
# Generation 6 - Current best internal CV score: 0.9630557545268278
# Generation 7 - Current best internal CV score: 0.9630557545268278
# Generation 8 - Current best internal CV score: 0.9630557545268278
# Generation 9 - Current best internal CV score: 0.9630557545268278
# Generation 10 - Current best internal CV score: 0.9630557545268278
# Generation 11 - Current best internal CV score: 0.9630557545268278
# Generation 12 - Current best internal CV score: 0.9630557545268278
# Generation 13 - Current best internal CV score: 0.9630557545268278
# Generation 14 - Current best internal CV score: 0.9630557545268278
# ...

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,int(n_observations/2)),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_features, train_target)
print(tpot.score(test_features, test_target))
tpot.export('tpot_knn_segmentation_half2.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.9376555446352718
# Generation 2 - Current best internal CV score: 0.9376555446352718
# Generation 3 - Current best internal CV score: 0.9532458229914544
# Generation 4 - Current best internal CV score: 0.9543968949376154
# Generation 5 - Current best internal CV score: 0.9543968949376154
# Generation 6 - Current best internal CV score: 0.9543968949376154
# Generation 7 - Current best internal CV score: 0.9630557545268278
# Generation 8 - Current best internal CV score: 0.9630557545268278
# Generation 9 - Current best internal CV score: 0.9630557545268278
# Generation 10 - Current best internal CV score: 0.9630557545268278
# Generation 11 - Current best internal CV score: 0.9630557545268278
# Generation 12 - Current best internal CV score: 0.9630557545268278
# Generation 13 - Current best internal CV score: 0.9630557545268278
# Generation 14 - Current best internal CV score: 0.9630557545268278
# ...

# %% [markdown]
# ### Solar-flare_2

# %%
solar = fetch_data('solar-flare_2')
n_observations = solar.size
# Out:
# (1066, 13)

# %%
solar_features = solar.drop('target', axis = 1)
train_features, test_features, train_target, test_target = train_test_split(solar_features, solar['target'], train_size = 0.75, test_size = 0.25, random_state = 42)

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,101),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_features, train_target)
print(tpot.score(test_features, test_target))
tpot.export('tpot_KNN_solar3.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.7622012578616353
# Generation 2 - Current best internal CV score: 0.7622012578616353
# Generation 3 - Current best internal CV score: 0.7622012578616353
# Generation 4 - Current best internal CV score: 0.7622012578616353
# Generation 5 - Current best internal CV score: 0.7622012578616353
# Generation 6 - Current best internal CV score: 0.7622012578616353
# Generation 7 - Current best internal CV score: 0.7622012578616353
# Generation 8 - Current best internal CV score: 0.7622012578616353
# Generation 9 - Current best internal CV score: 0.7622012578616353
# Generation 10 - Current best internal CV score: 0.7622012578616353
# Generation 11 - Current best internal CV score: 0.7622012578616353
# Generation 12 - Current best internal CV score: 0.7622012578616353
# Generation 13 - Current best internal CV score: 0.7622012578616353
# Generation 14 - Current best internal CV score: 0.7622012578616353
# ...

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,int(n_observations/2)),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_features, train_target)
print(tpot.score(test_features, test_target))
tpot.export('tpot_KNN_solar_half2.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.7572012578616353
# Generation 2 - Current best internal CV score: 0.7572012578616353
# Generation 3 - Current best internal CV score: 0.7622012578616353
# Generation 4 - Current best internal CV score: 0.7622012578616353
# Generation 5 - Current best internal CV score: 0.7622012578616353
# Generation 6 - Current best internal CV score: 0.7622012578616353
# Generation 7 - Current best internal CV score: 0.7622012578616353
# Generation 8 - Current best internal CV score: 0.7622012578616353
# Generation 9 - Current best internal CV score: 0.7622012578616353
# Generation 10 - Current best internal CV score: 0.7622012578616353
# Generation 11 - Current best internal CV score: 0.7622012578616353
# Generation 12 - Current best internal CV score: 0.7622012578616353
# Generation 13 - Current best internal CV score: 0.7622012578616353
# Generation 14 - Current best internal CV score: 0.7622012578616353
# ...

# %% [markdown]
# ### yeast

# %%
yeast = fetch_data('yeast')
n_observations = yeast.size
# Out:
# (1479, 9)

# %%
yeast_features = yeast.drop('target', axis = 1)
train_features, test_features, train_target, test_target = train_test_split(yeast_features, yeast['target'], train_size = 0.75, test_size = 0.25, random_state = 42)

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,101),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_features, train_target)
print(tpot.score(test_features, test_target))
tpot.export('tpot_knn_yeast3.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.6041090864620277
# Generation 2 - Current best internal CV score: 0.6041090864620277
# Generation 3 - Current best internal CV score: 0.6041090864620277
# Generation 4 - Current best internal CV score: 0.604117239411357
# Generation 5 - Current best internal CV score: 0.604117239411357
# Generation 6 - Current best internal CV score: 0.604117239411357
# Generation 7 - Current best internal CV score: 0.604117239411357
# Generation 8 - Current best internal CV score: 0.604117239411357
# Generation 9 - Current best internal CV score: 0.604117239411357
# Generation 10 - Current best internal CV score: 0.604117239411357
# Generation 11 - Current best internal CV score: 0.604117239411357
# Generation 12 - Current best internal CV score: 0.604117239411357
# Generation 13 - Current best internal CV score: 0.604117239411357
# Generation 14 - Current best internal CV score: 0.604117239411357
# ...

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,int(n_observations/2)),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_features, train_target)
print(tpot.score(test_features, test_target))
tpot.export('tpot_knn_yeast_half2.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.5986873751579633
# Generation 2 - Current best internal CV score: 0.6023235905588847
# Generation 3 - Current best internal CV score: 0.6023235905588847
# Generation 4 - Current best internal CV score: 0.6023235905588847
# Generation 5 - Current best internal CV score: 0.6023235905588847
# Generation 6 - Current best internal CV score: 0.6023235905588847
# Generation 7 - Current best internal CV score: 0.6023235905588847
# Generation 8 - Current best internal CV score: 0.6023235905588847
# Generation 9 - Current best internal CV score: 0.6023235905588847
# Generation 10 - Current best internal CV score: 0.604117239411357
# Generation 11 - Current best internal CV score: 0.604117239411357
# Generation 12 - Current best internal CV score: 0.604117239411357
# Generation 13 - Current best internal CV score: 0.604117239411357
# Generation 14 - Current best internal CV score: 0.604117239411357
# ...

# %% [markdown]
# ### Wine-quality

# %%
wine = fetch_data('wine-quality-white')
n_observations =  wine.size
# Out:
# (4893, 12)

# %%
wine_features = wine.drop('target', axis = 1)
train_features, test_features, train_target, test_target = train_test_split(wine_features, wine['target'], train_size = 0.75, test_size = 0.25, random_state = 42)

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,101),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_features, train_target)
print(tpot.score(test_features, test_target))
tpot.export('tpot_knn_wine3.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.6034370341733238
# Generation 2 - Current best internal CV score: 0.6034370341733238
# Generation 3 - Current best internal CV score: 0.6034370341733238
# Generation 4 - Current best internal CV score: 0.6034370341733238
# Generation 5 - Current best internal CV score: 0.6034370341733238
# Generation 6 - Current best internal CV score: 0.6034370341733238
# Generation 7 - Current best internal CV score: 0.6034370341733238
# Generation 8 - Current best internal CV score: 0.6034370341733238
# Generation 9 - Current best internal CV score: 0.6034370341733238
# Generation 10 - Current best internal CV score: 0.6034370341733238
# Generation 11 - Current best internal CV score: 0.6034370341733238
# Generation 12 - Current best internal CV score: 0.6034370341733238
# Generation 13 - Current best internal CV score: 0.6034370341733238
# Generation 14 - Current best internal CV score: 0.6034370341733238
# ...

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,int(n_observations/2)),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_features, train_target)
print(tpot.score(test_features, test_target))
tpot.export('tpot_knn_wine_half2.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.6009843463650185
# Generation 2 - Current best internal CV score: 0.6037080268093126
# Generation 3 - Current best internal CV score: 0.6037080268093126
# Generation 4 - Current best internal CV score: 0.6037080268093126
# Generation 5 - Current best internal CV score: 0.6045258372334217
# Generation 6 - Current best internal CV score: 0.6045258372334217
# Generation 7 - Current best internal CV score: 0.6045258372334217
# Generation 8 - Current best internal CV score: 0.6045258372334217
# Generation 9 - Current best internal CV score: 0.6045258372334217
# Generation 10 - Current best internal CV score: 0.6045258372334217
# Generation 11 - Current best internal CV score: 0.6045258372334217
# Generation 12 - Current best internal CV score: 0.6045258372334217
# Generation 13 - Current best internal CV score: 0.6045258372334217
# Generation 14 - Current best internal CV score: 0.6045258372334217
# ...

# %% [markdown]
# ### Waveform

# %%
wave = fetch_data('waveform-40')
n_observations = wave.size
# Out:
# (5000, 41)

# %%
wave_features = wave.drop('target', axis = 1)
train_features, test_features, train_target, test_target = train_test_split(wave_features, wave['target'], train_size = 0.75, test_size = 0.25, random_state = 42)

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,101),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_features, train_target)
print(tpot.score(test_features, test_target))
tpot.export('tpot_knn_wave3.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.8568
# Generation 2 - Current best internal CV score: 0.8568
# Generation 3 - Current best internal CV score: 0.8568
# Generation 4 - Current best internal CV score: 0.8568
# Generation 5 - Current best internal CV score: 0.8568
# Generation 6 - Current best internal CV score: 0.8568
# Generation 7 - Current best internal CV score: 0.8568
# Generation 8 - Current best internal CV score: 0.8568
# Generation 9 - Current best internal CV score: 0.8568
# Generation 10 - Current best internal CV score: 0.8568
# Generation 11 - Current best internal CV score: 0.8568
# Generation 12 - Current best internal CV score: 0.8568
# Generation 13 - Current best internal CV score: 0.8568
# Generation 14 - Current best internal CV score: 0.8568
# Generation 15 - Current best internal CV score: 0.8568
# Generation 16 - Current best internal CV score: 0.8568
# Generation 17 - Current best internal CV score: 0.8568
# ...

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,int(n_observations/2)),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_features, train_target)
print(tpot.score(test_features, test_target))
tpot.export('tpot_knn_wave_half2.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.8562666666666665
# Generation 2 - Current best internal CV score: 0.8565333333333334
# Generation 3 - Current best internal CV score: 0.8565333333333334
# Generation 4 - Current best internal CV score: 0.8565333333333334
# Generation 5 - Current best internal CV score: 0.8565333333333334
# Generation 6 - Current best internal CV score: 0.8568000000000001
# Generation 7 - Current best internal CV score: 0.8568000000000001
# Generation 8 - Current best internal CV score: 0.8568000000000001
# Generation 9 - Current best internal CV score: 0.8570666666666668
# Generation 10 - Current best internal CV score: 0.8570666666666668
# Generation 11 - Current best internal CV score: 0.8570666666666668
# Generation 12 - Current best internal CV score: 0.8570666666666668
# Generation 13 - Current best internal CV score: 0.8570666666666668
# Generation 14 - Current best internal CV score: 0.8570666666666668
# ...

# %% [markdown]
# ### twonorm

# %%
twonorm = fetch_data('twonorm')
n_observations = twonorm.size
# Out:
# (7400, 21)

# %%
twonorm_features = twonorm.drop('target', axis = 1)
train_features, test_features, train_target, test_target = train_test_split(twonorm_features, twonorm['target'], train_size = 0.75, test_size = 0.25, random_state = 42)

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,101),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_features, train_target)
print(tpot.score(test_features, test_target))
tpot.export('tpot_knn_twonorm3.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.9760360360360361
# Generation 2 - Current best internal CV score: 0.9760360360360361
# Generation 3 - Current best internal CV score: 0.9760360360360361
# Generation 4 - Current best internal CV score: 0.9760360360360361
# Generation 5 - Current best internal CV score: 0.9762162162162162
# Generation 6 - Current best internal CV score: 0.9762162162162162
# Generation 7 - Current best internal CV score: 0.9762162162162162
# Generation 8 - Current best internal CV score: 0.9762162162162162
# Generation 9 - Current best internal CV score: 0.9762162162162162
# Generation 10 - Current best internal CV score: 0.9762162162162162
# Generation 11 - Current best internal CV score: 0.9762162162162162
# Generation 12 - Current best internal CV score: 0.9762162162162162
# Generation 13 - Current best internal CV score: 0.9762162162162162
# Generation 14 - Current best internal CV score: 0.9762162162162162
# ...

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,int(n_observations/2)),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_features, train_target)
print(tpot.score(test_features, test_target))
tpot.export('tpot_knn_twonorm_half2.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.9781981981981982
# Generation 2 - Current best internal CV score: 0.9781981981981982
# Generation 3 - Current best internal CV score: 0.9781981981981982
# Generation 4 - Current best internal CV score: 0.9781981981981982
# Generation 5 - Current best internal CV score: 0.9781981981981982
# Generation 6 - Current best internal CV score: 0.9781981981981982
# Generation 7 - Current best internal CV score: 0.9781981981981982
# Generation 8 - Current best internal CV score: 0.9781981981981982
# Generation 9 - Current best internal CV score: 0.9781981981981982
# Generation 10 - Current best internal CV score: 0.9781981981981982
# Generation 11 - Current best internal CV score: 0.9781981981981982
# Generation 12 - Current best internal CV score: 0.9781981981981982
# Generation 13 - Current best internal CV score: 0.9781981981981982
# Generation 14 - Current best internal CV score: 0.9781981981981982
# ...

# %% [markdown]
# ### Titanic

# %%
titanic = fetch_data('titanic')
n_observations = titanic.size
# Out:
# (2201, 4)

# %%
titanic_features = titanic.drop('target', axis = 1)
train_features, test_features, train_target, test_target = train_test_split(titanic_features, titanic['target'], train_size = 0.75, test_size = 0.25, random_state = 42)

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,101),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_features, train_target)
print(tpot.score(test_features, test_target))
tpot.export('tpot_knn_titanic3.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.8078787878787879
# Generation 2 - Current best internal CV score: 0.8078787878787879
# Generation 3 - Current best internal CV score: 0.8078787878787879
# Generation 4 - Current best internal CV score: 0.8078787878787879
# Generation 5 - Current best internal CV score: 0.8078787878787879
# Generation 6 - Current best internal CV score: 0.8078787878787879
# Generation 7 - Current best internal CV score: 0.8078787878787879
# Generation 8 - Current best internal CV score: 0.8078787878787879
# Generation 9 - Current best internal CV score: 0.8078787878787879
# Generation 10 - Current best internal CV score: 0.8078787878787879
# Generation 11 - Current best internal CV score: 0.8078787878787879
# Generation 12 - Current best internal CV score: 0.8078787878787879
# Generation 13 - Current best internal CV score: 0.8078787878787879
# Generation 14 - Current best internal CV score: 0.8078787878787879
# ...

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,int(n_observations/2)),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_features, train_target)
print(tpot.score(test_features, test_target))
tpot.export('tpot_knn_titanic_half2.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.8054545454545453
# Generation 2 - Current best internal CV score: 0.8078787878787879
# Generation 3 - Current best internal CV score: 0.8078787878787879
# Generation 4 - Current best internal CV score: 0.8078787878787879
# Generation 5 - Current best internal CV score: 0.8078787878787879
# Generation 6 - Current best internal CV score: 0.8078787878787879
# Generation 7 - Current best internal CV score: 0.8078787878787879
# Generation 8 - Current best internal CV score: 0.8078787878787879
# Generation 9 - Current best internal CV score: 0.8078787878787879
# Generation 10 - Current best internal CV score: 0.8078787878787879
# Generation 11 - Current best internal CV score: 0.8078787878787879
# Generation 12 - Current best internal CV score: 0.8078787878787879
# Generation 13 - Current best internal CV score: 0.8078787878787879
# Generation 14 - Current best internal CV score: 0.8078787878787879
# ...

# %% [markdown]
# ### Gametes_epistasis_2

# %%
gametes1 = fetch_data('GAMETES_Epistasis_2-Way_1000atts_0.4H_EDM-1_EDM-1_1')
n_observations = gametes1.size
# Out:
# (1600, 1001)

# %%
gametes1_features = gametes1.drop('target', axis = 1)
train_features, test_features, train_target, test_target = train_test_split(gametes1_features, gametes1['target'], train_size = 0.75, test_size = 0.25, random_state = 42)

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,101),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_features, train_target)
print(tpot.score(test_features, test_target))
tpot.export('tpot_knn_gametes1_3.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.53
# Generation 2 - Current best internal CV score: 0.53
# Generation 3 - Current best internal CV score: 0.53
# Generation 4 - Current best internal CV score: 0.53
# Generation 5 - Current best internal CV score: 0.53
# Generation 6 - Current best internal CV score: 0.53
# Generation 7 - Current best internal CV score: 0.53
# Generation 8 - Current best internal CV score: 0.53
# Generation 9 - Current best internal CV score: 0.53
# Generation 10 - Current best internal CV score: 0.53
# Generation 11 - Current best internal CV score: 0.53
# Generation 12 - Current best internal CV score: 0.53
# Generation 13 - Current best internal CV score: 0.53
# Generation 14 - Current best internal CV score: 0.53
# Generation 15 - Current best internal CV score: 0.53
# Generation 16 - Current best internal CV score: 0.53
# Generation 17 - Current best internal CV score: 0.53
# Generation 18 - Current best internal CV score: 0.53
# ...

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,int(n_observations/2)),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_features, train_target)
print(tpot.score(test_features, test_target))
tpot.export('tpot_knn_gametes_half1_2.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.5466666666666666
# Generation 2 - Current best internal CV score: 0.5466666666666666
# Generation 3 - Current best internal CV score: 0.5533333333333333
# Generation 4 - Current best internal CV score: 0.5533333333333333
# Generation 5 - Current best internal CV score: 0.5533333333333333
# Generation 6 - Current best internal CV score: 0.5533333333333333
# Generation 7 - Current best internal CV score: 0.5533333333333333
# Generation 8 - Current best internal CV score: 0.5533333333333333
# Generation 9 - Current best internal CV score: 0.5533333333333333
# Generation 10 - Current best internal CV score: 0.5533333333333333
# Generation 11 - Current best internal CV score: 0.5533333333333333
# Generation 12 - Current best internal CV score: 0.5533333333333333
# Generation 13 - Current best internal CV score: 0.5533333333333333
# Generation 14 - Current best internal CV score: 0.5533333333333333
# ...

# %% [markdown]
# ### Gametes Heterogeneity

# %%
gametes2 = fetch_data('GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_75_EDM-2_001')

# %%
n_observations = gametes2.size
# Out:
# (1600, 21)

# %%
gametes2_features = gametes2.drop('target', axis = 1)
train_features, test_features, train_target, test_target = train_test_split(gametes2_features, gametes2['target'], train_size = 0.75, test_size = 0.25, random_state = 42)

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,101),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_features, train_target)
print(tpot.score(test_features, test_target))
tpot.export('tpot_knn_gametes2_3.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.6141666666666666
# Generation 2 - Current best internal CV score: 0.6141666666666666
# Generation 3 - Current best internal CV score: 0.6141666666666666
# Generation 4 - Current best internal CV score: 0.6141666666666666
# Generation 5 - Current best internal CV score: 0.6141666666666666
# Generation 6 - Current best internal CV score: 0.6141666666666666
# Generation 7 - Current best internal CV score: 0.6141666666666666
# Generation 8 - Current best internal CV score: 0.6141666666666666
# Generation 9 - Current best internal CV score: 0.6141666666666666
# Generation 10 - Current best internal CV score: 0.6141666666666666
# Generation 11 - Current best internal CV score: 0.6141666666666666
# Generation 12 - Current best internal CV score: 0.6141666666666666
# Generation 13 - Current best internal CV score: 0.6141666666666666
# Generation 14 - Current best internal CV score: 0.6141666666666666
# ...

# %%
#KNN with default values
tpot_config = {
  'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1,int(n_observations/2)),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

# %%
tpot = TPOTClassifier(generations=100, population_size=100, verbosity=2,
                       random_state = 42, config_dict=tpot_config, template = 'Classifier' )

tpot.fit(train_features, train_target)
print(tpot.score(test_features, test_target))
tpot.export('tpot_knn_gametes2_half2.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.6125
# Generation 2 - Current best internal CV score: 0.6125
# Generation 3 - Current best internal CV score: 0.6125
# Generation 4 - Current best internal CV score: 0.6125
# Generation 5 - Current best internal CV score: 0.6125
# Generation 6 - Current best internal CV score: 0.6125
# Generation 7 - Current best internal CV score: 0.6125
# Generation 8 - Current best internal CV score: 0.6125
# Generation 9 - Current best internal CV score: 0.6141666666666665
# Generation 10 - Current best internal CV score: 0.6141666666666665
# Generation 11 - Current best internal CV score: 0.6141666666666665
# Generation 12 - Current best internal CV score: 0.6141666666666665
# Generation 13 - Current best internal CV score: 0.6141666666666665
# Generation 14 - Current best internal CV score: 0.6141666666666665
# Generation 15 - Current best internal CV score: 0.6141666666666665
# Generation 16 - Current best internal CV score: 0.6141666666666665
# ...
